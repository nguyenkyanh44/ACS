# %% [markdown]
# ## This is a report detailing all of my findings in regards to optimizing our Google Ad Budgets with the objective of bringing in more new patients to ACS.

# %% [markdown]
# ### The first order of business is to provide update on the new patient numbers and averages since the last time we met.

# %%
import pandas as pd
import numpy as np
from datetime import datetime, date 
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import Image

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\ACS Project 2\\New Patient Numbers Analysis\\df.csv', index_col = 0)

# %%
df2 = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\ACS Project 2\\New Patient Numbers Analysis\\df2.csv', index_col = 0)

# %%
locations_with_27_months = list(df2[df2['Number of Months of Data'] == 27]['Location'])

# %%
_27_months = ['Jan 22','Feb 22','Mar 22','Apr 22','May 22','Jun 22','Jul 22','Aug 22','Sep 22','Oct 22','Nov 22',
 'Dec 22',
 'Jan 23',
 'Feb 23',
 'Mar 23',
 'Apr 23',
 'May 23',
 'Jun 23',
 'Jul 23',
 'Aug 23',
 'Sep 23',
 'Oct 23',
 'Nov 23',
 'Dec 23', 'Jan 24', 'Feb 24', 'Mar 24']

# %% [markdown]
# ## Here are the new patient numbers for all clinics (includes all available data):

# %%
for i in locations_with_27_months:
    labels = _27_months
    values = df[df['Location'] == i]['Total Number of New Patients'].values
    plt.figure(figsize=(15,6))
    plt.axhline(y = df2[df2['Location'] == i]['Average Number of New Patients per Month'][df2[df2['Location'] == i]['Average Number of New Patients per Month'].index[0]], color = 'g', linestyle = '-', label = 'Average')
    plt.axhline(y = df2[df2['Location'] == i]['Ideal'][df2[df2['Location'] == i]['Ideal'].index[0]], color = 'r', linestyle = '--', label = 'Ideal')
    plt.xticks(rotation=30, ha='center')
    plt.xlabel('Month')
    plt.ylabel('Count')
    plt.title(f'{i.title()}')
    plt.legend(bbox_to_anchor = (1.15, 1), loc = 'upper center')
    plt.plot(labels, values)
    plt.show()

# %%
months_18 = ['Oct 22','Nov 22','Dec 22','Jan 23','Feb 23','Mar 23','Apr 23','May 23','Jun 23','Jul 23','Aug 23','Sep 23',
 'Oct 23',
 'Nov 23',
 'Dec 23', 'Jan 24', 'Feb 24', 'Mar 24']

# %%
locations_with_18_months = list(df2[df2['Number of Months of Data'] == 18]['Location'])

# %%
locations_with_18_months
# Out:
# ['gresham',
#  'keizer',
#  'e. vancouver',
#  's. salem',
#  'vancouver',
#  'woodburn',
#  'salem',
#  'mcminville']

# %%
for i in locations_with_18_months:
    labels = months_18
    values = df[df['Location'] == i]['Total Number of New Patients'].values
    plt.figure(figsize=(15,6))
    plt.axhline(y = df2[df2['Location'] == i]['Average Number of New Patients per Month'][df2[df2['Location'] == i]['Average Number of New Patients per Month'].index[0]], color = 'g', linestyle = '-', label = 'Average')
    plt.axhline(y = df2[df2['Location'] == i]['Ideal'][df2[df2['Location'] == i]['Ideal'].index[0]], color = 'r', linestyle = '--', label = 'Ideal')
    plt.xticks(rotation=30, ha='center')
    plt.xlabel('Month')
    plt.ylabel('Count')
    plt.title(f'{i.title()}')
    plt.legend(bbox_to_anchor = (1.15, 1), loc = 'upper center')
    plt.plot(labels, values)
    plt.show()

# %%
months_15 = ['Jan 23','Feb 23','Mar 23','Apr 23','May 23','Jun 23','Jul 23','Aug 23','Sep 23','Oct 23','Nov 23','Dec 23', 'Jan 24', 'Feb 24', 'Mar 24']
bend_forest_grove = ['bend', 'forest grove']
for i in bend_forest_grove:
    labels = months_15
    values = df[df['Location'] == i]['Total Number of New Patients'].values
    plt.figure(figsize=(15,6))
    plt.axhline(y = df2[df2['Location'] == i]['Average Number of New Patients per Month'][df2[df2['Location'] == i]['Average Number of New Patients per Month'].index[0]], color = 'g', linestyle = '-', label = 'Average')
    plt.axhline(y = df2[df2['Location'] == i]['Ideal'][df2[df2['Location'] == i]['Ideal'].index[0]], color = 'r', linestyle = '--', label = 'Ideal')
    plt.xticks(rotation=30, ha='center')
    plt.xlabel('Month')
    plt.ylabel('Count')
    plt.title(f'{i.title()}')
    plt.legend(bbox_to_anchor = (1.15, 1), loc = 'upper center')
    plt.plot(labels, values)
    plt.show()

# %%
months_10 = ['Jun 23','Jul 23','Aug 23','Sep 23','Oct 23','Nov 23','Dec 23', 'Jan 24', 'Feb 24', 'Mar 24']
labels = months_10
values = df[df['Location'] == 'north portland']['Total Number of New Patients'].values
plt.figure(figsize=(15,6))
plt.axhline(y = df2[df2['Location'] == 'north portland']['Average Number of New Patients per Month'][df2[df2['Location'] == 'north portland']['Average Number of New Patients per Month'].index[0]], color = 'g', linestyle = '-', label = 'Average')
plt.axhline(y = df2[df2['Location'] == 'north portland']['Ideal'][df2[df2['Location'] == 'north portland']['Ideal'].index[0]], color = 'r', linestyle = '--', label = 'Ideal')
plt.xticks(rotation=30, ha='center')
plt.xlabel('Month')
plt.ylabel('Count')
plt.title(f'{'north portland'.title()}')
plt.legend(bbox_to_anchor = (1.15, 1), loc = 'upper center')
plt.plot(labels, values)
plt.show()

# %%
months_6 = ['Oct 23','Nov 23','Dec 23', 'Jan 24', 'Feb 24', 'Mar 24']
labels = months_6
values = df[df['Location'] == 'hazel dell']['Total Number of New Patients'].values
plt.figure(figsize=(15,6))
plt.axhline(y = df2[df2['Location'] == 'hazel dell']['Average Number of New Patients per Month'][df2[df2['Location'] == 'hazel dell']['Average Number of New Patients per Month'].index[0]], color = 'g', linestyle = '-', label = 'Average')
plt.axhline(y = df2[df2['Location'] == 'hazel dell']['Ideal'][df2[df2['Location'] == 'hazel dell']['Ideal'].index[0]], color = 'r', linestyle = '--', label = 'Ideal')
plt.xticks(rotation=30, ha='center')
plt.xlabel('Month')
plt.ylabel('Count')
plt.title(f'{'hazel dell'.title()}')
plt.legend(bbox_to_anchor = (1.15, 1), loc = 'upper center')
plt.plot(labels, values)
plt.show()

# %% [markdown]
# ## In general, for the months of December 2023, January 2024, and February 2024, most clinics have been trending either downwards in terms of their NP numbers or are just hovering around their averages. Here are the most noteworthy observations from these graphs:
#
# ## 1. SE PDX hit the lowest number of new patients it has ever had since we first started tracking this data. It's last significant peak occurred in June of 2023 when it brought in 39 new patients. It has not been anywhere close to that number since. Since we started running Google Ads for SE PDX (the current campaign was created in July 2023), it has been averaging 6 new patients below its ideal (compared to just 1 n.p. below its ideal since January of 2022). Fortunately, it is the only clinics that has had such a drastic drop in its averages since we started running Google Ads.
#
# ## 2. Given the new patient numbers from March, most of the clinics regressed to how they had been historically speaking. For example, NE PDX had been performing poorly from Oct 23 to Feb 24, but in March boomed far above its average. This should not come as much of a surprise since NE PDX has been one of our best-performining clinics. As an example of the contrary, Vancouver had 31 new patients in February, the most of any clinic, even though historically it has been a subpar clinic at best. Then in March, Vancouver only recorded 12 new patients, the largest drop of any clinic.

# %% [markdown]
# ## Below is our updated dataset of clinics and their performance metrics.

# %%
def highlight_columns(col):
   color = 'pink' if col.name in ['Average Number Minus Ideal', 'Proportion of Actual to Target'] else 'white' 
   return ['background-color: {}'.format(color) for _ in col]
# calling method using apply()
styled_df = df2.style.apply(highlight_columns)
# to show the highlighted column
styled_df
# Out:
# <style type="text/css">
# ...

# %% [markdown]
# ## Let's now take a look at each of the ad campaigns for all of the clinics.

# %%
df3 = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\Main Project\\campaign names.xlsx', index_col = 0)

# %%
df3.reset_index(inplace = True, drop = True)

# %%
df3.columns = df3.loc[1].values

# %%
df3.dropna(inplace = True)

# %%
df3.drop(1, axis = 0, inplace = True)

# %%
df3.reset_index(inplace = True, drop = True)

# %%
df3
# Out:
#                                              Campaign Budget name  \
# 0   W. Woodburn, OR | P. Max | 6 ZIPS (Presence) |...          --
# 1   N. Portland, OR | P. Max | 10 ZIPS (Presence) ...          --
# 2   F. Forest Grove, OR | P. Max | ZIPS (Presence)...          --
# 3   S. South Salem, OR  | P. Max | 5 miles (P or I...          --
# 4   B. Beaverton, OR | P. Max | 5 Miles, Top 8 Zip...          --
# 5   H. Hillsboro, OR | P. Max | 7 ZIPS (P. or I.) ...          --
# 6   T. Tigard, OR | P. Max | ZIPS (Presence) | Est...          --
# 7   G. Gresham, OR | P. Max | 8 ZIPS (Presence) | ...          --
# 8   S.E. Portland, OR | P. Max | 12 ZIPS (Presence...          --
# 9   N.E. Portland, OR | P. Max | 9 ZIPS (Presence)...          --
# 10  M. McMinnville, OR | P. Max | 5 ZIPS (Presence...          --
# 11  E. Vancouver, WA | P. Max | 8 ZIPS (Presence) ...          --
# 12  H. Hazel Dell, WA | P. Max | 8 ZIPS (P. or I.)...          --
# ...

# %%
df3['Status'].unique()
# Out:
# array(['Eligible (Limited)'], dtype=object)

# %%
df3['Status reasons'].unique()
# Out:
# array(['bidding strategy learning; limited by budget; most asset groups limited by policy',
#        'bidding strategy learning; most asset groups limited by policy',
#        'limited by budget; most asset groups limited by policy',
#        'most asset groups limited by policy',
#        'bidding strategy limited; unknown'], dtype=object)

# %% [markdown]
# ## All of the campaigns have a limited status, with the reasoning for most of them being that they are limited by their budgets.

# %%
beaverton = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\beaverton conversions.csv')
e_vancouver = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\east vancouver conversions.csv')
forest_grove = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\forest grove conversions.csv')
hillsboro = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\hillsboro conversions.csv')
keizer = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\keizer conversions.csv')
mcminville = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\mcminville conversions.csv')
salem = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\salem conversions.csv')
se_pdx = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\se pdx conversions.csv')
s_salem = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\south salem conversions.csv')
tigard = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\tigard conversions.csv')
vancouver = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\vancouver conversions.csv')
woodburn = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\woodburn conversions.csv')

# %%
def clean_df(df):
    df = pd.DataFrame(df.iloc[9:, [0, 3]])
    df.reset_index(inplace = True, drop = True)
    return df

# %%
beaverton = clean_df(beaverton)
e_vancouver = clean_df(e_vancouver)
forest_grove = clean_df(forest_grove)
hillsboro = clean_df(hillsboro)
keizer = clean_df(keizer)
mcminville = clean_df(mcminville)
salem = clean_df(salem)
se_pdx = clean_df(se_pdx)
s_salem = clean_df(s_salem)
tigard = clean_df(tigard)
vancouver = clean_df(vancouver)
woodburn = clean_df(woodburn)

# %%
budget_changes = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\Main Project\\budget changes.xlsx', index_col = 0)

# %% [markdown]
# ## This is a dataset containing budget changes for all of our current active campaigns.

# %%
budget_changes
# Out:
#                   Date & time                                  User  \
# 0    Feb 16, 2024, 5:10:07 PM    admin@accidentcarechiropractic.com
# 1     Feb 2, 2024, 3:00:24 PM    admin@accidentcarechiropractic.com
# 2    Jan 31, 2024, 8:21:45 PM    admin@accidentcarechiropractic.com
# 3    Jan 19, 2024, 8:54:34 AM    admin@accidentcarechiropractic.com
# 4    Jan 9, 2024, 11:49:55 AM              24.7.sales.com@gmail.com
# 5    Dec 29, 2023, 8:58:45 PM    admin@accidentcarechiropractic.com
# 6    Dec 29, 2023, 8:44:55 PM    admin@accidentcarechiropractic.com
# 7    Dec 20, 2023, 8:30:00 AM  donovan@accidentcarechiropractic.com
# 8     Dec 5, 2023, 6:10:25 PM    admin@accidentcarechiropractic.com
# 9     Dec 5, 2023, 6:09:57 PM    admin@accidentcarechiropractic.com
# 10    Dec 5, 2023, 5:33:47 PM    admin@accidentcarechiropractic.com
# 11   Aug 24, 2023, 6:20:44 AM  donovan@accidentcarechiropractic.com
# 12   Aug 24, 2023, 6:13:56 AM  donovan@accidentcarechiropractic.com
# ...

# %%
index_to_examine = []
for i in range(budget_changes.shape[0]):
    if budget_changes['Changes'].values[i].split('\n')[0] == 'Budget created':
        index_to_examine.append(i)

# %%
budget_changes['Date & time'] = pd.to_datetime(budget_changes['Date & time'])

# %% [markdown]
# ## This dataset contains the dates of when each campaign was created.

# %%
budget_changes.iloc[index_to_examine, :].sort_values(by = 'Date & time')
# Out:
#            Date & time                                  User  \
# 34 2023-07-07 08:26:22  donovan@accidentcarechiropractic.com
# 32 2023-07-07 11:26:27  donovan@accidentcarechiropractic.com
# 30 2023-07-10 10:11:52  donovan@accidentcarechiropractic.com
# 29 2023-07-11 12:24:03  donovan@accidentcarechiropractic.com
# 28 2023-07-12 12:27:35  donovan@accidentcarechiropractic.com
# 26 2023-07-14 11:44:48  donovan@accidentcarechiropractic.com
# 25 2023-07-15 13:49:03  donovan@accidentcarechiropractic.com
# 24 2023-07-17 10:17:01  donovan@accidentcarechiropractic.com
# 23 2023-07-17 18:03:46  donovan@accidentcarechiropractic.com
# 22 2023-07-17 18:46:51  donovan@accidentcarechiropractic.com
# 21 2023-07-18 09:32:14  donovan@accidentcarechiropractic.com
# 20 2023-07-19 10:00:07  donovan@accidentcarechiropractic.com
# 19 2023-07-20 07:34:39  donovan@accidentcarechiropractic.com
# 16 2023-07-21 09:34:28  donovan@accidentcarechiropractic.com
# ...

# %%
df11 = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\Main Project\\number of budget changes.xlsx', index_col = 0)

# %%
df11
# Out:
#                                              Campaign  \
# 0   N. Portland, OR | P. Max | DF's Zips (P or I) ...
# 1   G. Gresham, OR | P. Max | 5 Miles (Presence) |...
# 2   C. Clackamas, OR | P. Max | 5 Miles + 11 Zips ...
# 3   N.E. Portland, OR | P. Max | 5 miles (Presence...
# 4   H. Hazel Dell, WA | P. Max | 5 miles & to Nort...
# 5   V. Vancouver, WA | P. Max | 5 miles (Presence)...
# 6   B. Beaverton, OR | P. Max | 5 Miles, Top 8 Zip...
# 7   S. South Salem, OR  | P. Max | 5 miles (P or I...
# 8   S. Salem, OR | P. Max | 5 miles (P or I) | Est...
# 9   K. Keizer, OR | P. Max | 5 miles (P or I) | Es...
# 10  M. McMinnville, OR | P. Max | 10 miles (Presen...
# 11  S.E. Portland, OR | P. Max | 5 miles (Presence...
# 12  F. Forest Grove, OR | P. Max | 5 miles (Presen...
# 13  H. Hillsboro, OR | P. Max | 5 miles (P. or I.)...
# 14  E. Vancouver, WA | P. Max | Custom Locations (...
# 15  T. Tigard, OR | P. Max | 5 miles (Presence) | ...
# ...

# %%
fig, (ax1, ax2, ax3, ax4, ax5, ax6, ax7, ax8, ax9, ax10, ax11, ax12) = plt.subplots(12, figsize = (10, 20), constrained_layout = True)
labels = beaverton['Month'].values
values1 = beaverton['Conversions'].values
values2 = e_vancouver['Conversions'].values
ax1.plot(labels, values1)
ax1.set_xticklabels(labels = labels, rotation=30, ha='center')
ax1.set_xlabel('Month')
ax1.set_ylabel('Count')
ax1.set_title('Beaverton')
ax2.plot(labels, values2)
ax2.set_xticklabels(labels = labels, rotation=30, ha='center')
ax2.set_xlabel('Month')
ax2.set_ylabel('Count')
ax2.set_title('East Vancouver')
values3 = forest_grove['Conversions'].values
ax3.plot(labels, values3)
ax3.set_xticklabels(labels = labels, rotation=30, ha='center')
ax3.set_xlabel('Month')
ax3.set_ylabel('Count')
ax3.set_title('Forest Grove')
values4 = hillsboro['Conversions'].values
ax4.plot(labels, values4)
ax4.set_xticklabels(labels = labels, rotation=30, ha='center')
ax4.set_xlabel('Month')
ax4.set_ylabel('Count')
ax4.set_title('Hillsboro')
values5 = keizer['Conversions'].values
ax5.plot(labels, values5)
ax5.set_xticklabels(labels = labels, rotation=30, ha='center')
ax5.set_xlabel('Month')
ax5.set_ylabel('Count')
ax5.set_title('Keizer')
values6 = mcminville['Conversions'].values
ax6.plot(labels, values6)
ax6.set_xticklabels(labels = labels, rotation=30, ha='center')
ax6.set_xlabel('Month')
ax6.set_ylabel('Count')
ax6.set_title('Mcminville')
values7 = salem['Conversions'].values
ax7.plot(labels, values7)
ax7.set_xticklabels(labels = labels, rotation=30, ha='center')
ax7.set_xlabel('Month')
ax7.set_ylabel('Count')
ax7.set_title('Salem')
values8 = se_pdx['Conversions'].values
ax8.plot(labels, values8)
ax8.set_xticklabels(labels = labels, rotation=30, ha='center')
ax8.set_xlabel('Month')
ax8.set_ylabel('Count')
ax8.set_title('SE PDX')
values9 = s_salem['Conversions'].values
ax9.plot(labels, values9)
ax9.set_xticklabels(labels = labels, rotation=30, ha='center')
ax9.set_xlabel('Month')
ax9.set_ylabel('Count')
ax9.set_title('South Salem')
values10 = tigard['Conversions'].values
ax10.plot(labels, values10)
ax10.set_xticklabels(labels = labels, rotation=30, ha='center')
ax10.set_xlabel('Month')
ax10.set_ylabel('Count')
ax10.set_title('Tigard')
values11 = vancouver['Conversions'].values
ax11.plot(labels, values11)
ax11.set_xticklabels(labels = labels, rotation=30, ha='center')
ax11.set_xlabel('Month')
ax11.set_ylabel('Count')
ax11.set_title('Vancouver')
values12 = vancouver['Conversions'].values
ax12.plot(labels, values12)
ax12.set_xticklabels(labels = labels, rotation=30, ha='center')
ax12.set_xlabel('Month')
ax12.set_ylabel('Count')
ax12.set_title('Woodburn')
plt.show()

# %% [markdown]
# ## These are all clinics which had no budget changes and had their budgets set at $75 per day. For all of these clinics their conversions peaked in September of 2023 and has not significantly risen since then.

# %%
clackamas = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\clackamas conversions.csv')
ne_pdx = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\ne pdx conversions.csv')
hazel_dell = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\hazel dell conversions.csv')
gresham = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\gresham conversions.csv')
n_portland = pd.read_csv('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\north portland conversions.csv')

# %%
clackamas = clean_df(clackamas)
ne_pdx = clean_df(ne_pdx)
hazel_dell = clean_df(hazel_dell)
gresham = clean_df(gresham)
n_portland = clean_df(n_portland)

# %%
df4 = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\Main Project\\budget_changes.xlsx', index_col = 0)

# %%
fig, ax = plt.subplots(1, figsize = (15, 6), constrained_layout = True)
labels = beaverton['Month'].values
values = clackamas['Conversions'].values
ax.plot(labels, values1)
ax.set_xticklabels(labels = labels, rotation=30, ha='center')
ax.set_xlabel('Month')
ax.set_ylabel('Count')
ax.set_title('Clackamas Conversions')
# Out:
# Text(0.5, 1.0, 'Clackamas Conversions')

# %% [markdown]
# ## For Clackamas, its budget was set at $75 a day on the day it was created and hasn't changed since then.

# %%
df6 = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\df2.xlsx', index_col = 0)
df5 = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\df5.xlsx', index_col = 0)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, figsize = (15, 10))
fig.suptitle('Gresham')
labels_1 = df6['Date & time'].values
values_1 = df6['Budget Amount'].values
ax1.plot(labels_1, values_1, marker = 'o')
ax1.set_title('Budget')
ax1.set_xlabel('Month')
ax1.set_ylabel('Amount')
ax1.yaxis.set_major_formatter('${x:1.2f}')
labels_2 = gresham['Month'].values
values_2 = gresham['Conversions'].values
ax2.plot(labels_2, values_2, marker = 'o', color = 'r')
ax2.set_title('Conversions')
ax2.set_xlabel('Month')
ax2.set_ylabel('Count')
ax1.set_xlabel('Month')
ax1.set_ylabel('Count')
labels_3 = df5['Month'].values
values_3 = df5['Total Number of New Patients'].values
ax3.plot(labels_3, values_3, marker = 'o', color = 'g')
ax3.set_title('New Patients')
ax3.set_xlabel('Month')
ax3.set_ylabel('Count')
ax3.axhline(y = 15, color = 'r', linestyle = '--', label = 'Ideal')
ax3.legend(bbox_to_anchor = (.95, 1), loc = 'upper center')
fig.tight_layout()
plt.show()

# %%
df7 = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\df7.xlsx', index_col = 0)
df8 = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\df8.xlsx', index_col = 0)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, figsize = (15, 10))
fig.suptitle('NE PDX')
labels_1 = df7['Date & time'].values
values_1 = [75, 150, 75]
ax1.plot(labels_1, values_1, marker = 'o')
ax1.set_title('Budget')
ax1.set_xlabel('Month')
ax1.set_ylabel('Amount')
ax1.yaxis.set_major_formatter('${x:1.2f}')
labels_2 = ne_pdx.iloc[:8,0].values
values_2 = ne_pdx.iloc[:8,1].values
ax2.plot(labels_2, values_2, marker = 'o', color = 'r')
ax2.set_title('Conversions')
ax2.set_xlabel('Month')
ax2.set_ylabel('Count')
ax1.set_xlabel('Month')
ax1.set_ylabel('Count')
labels_3 = df8['Month'].values
values_3 = df8['Total Number of New Patients'].values
ax3.plot(labels_3, values_3, marker = 'o', color = 'g')
ax3.set_title('New Patients')
ax3.set_xlabel('Month')
ax3.set_ylabel('Count')
ax3.axhline(y = 15, color = 'r', linestyle = '--', label = 'Ideal')
ax3.legend(bbox_to_anchor = (.95, 1), loc = 'upper center')
fig.tight_layout()
plt.show()

# %%
df9 = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\df9.xlsx', index_col = 0)
df10 = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\Conversions data\\df10.xlsx', index_col = 0)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, figsize = (15, 10))
fig.suptitle('Hazel Dell')
labels_1 = df9['Date & time'].values
values_1 = [35, 35, 75]
ax1.plot(labels_1, values_1, marker = 'o')
ax1.set_title('Budget')
ax1.set_xlabel('Month')
ax1.set_ylabel('Amount')
ax1.yaxis.set_major_formatter('${x:1.2f}')
labels_2 = hazel_dell.iloc[1:8, 0].values
values_2 = hazel_dell.iloc[1:8, 1].values
ax2.plot(labels_2, values_2, marker = 'o', color = 'r')
ax2.set_title('Conversions')
ax2.set_xlabel('Month')
ax2.set_ylabel('Count')
ax1.set_xlabel('Month')
ax1.set_ylabel('Count')
labels_3 = df10['Month'].values
values_3 = df10['Total Number of New Patients'].values
ax3.plot(labels_3, values_3, marker = 'o', color = 'g')
ax3.set_title('New Patients')
ax3.set_xlabel('Month')
ax3.set_ylabel('Count')
ax3.axhline(y = 15, color = 'r', linestyle = '--', label = 'Ideal')
ax3.legend(bbox_to_anchor = (1.05, 1), loc = 'upper center')
fig.tight_layout()
plt.show()

# %%
n_pdx_conversions = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\Main Project\\n_pdx_converions.xlsx', index_col = 0)
n_pdx = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\Main Project\\n_pdx.xlsx', index_col = 0)
n_pdx_budget = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\Main Project\\n_pdx_budget.xlsx', index_col = 0)

# %%
budget_amount_no_dollar = [75, 150, 75, 230, 150, 75, 100, 50, 75]

# %%
fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, figsize=(15, 10))
fig.suptitle(f'{'North Portland'.title()}')
labels = n_pdx_conversions['Month'].values
conversions = n_pdx_conversions['Conversions'].values
clicks = n_pdx_conversions['Clicks'].values
impressions = n_pdx_conversions['Impressions'].values
np_numbers = n_pdx['Total Number of New Patients'].values[1:]
labels_2 = n_pdx['Month'].values[1:]
ax2.set_xticklabels(labels = labels, rotation=30, ha='center')
ax3.set_xticklabels(labels = labels, rotation=30, ha='center')
ax4.set_xticklabels(labels = labels, rotation=30, ha='center')
ax5.set_xticklabels(labels = labels, rotation=30, ha='center')
ax2.plot(labels, conversions, marker = 'o', color='red')
ax3.plot(labels, clicks, marker = 'o', color='b')
ax4.plot(labels, impressions, marker = 'o', color = 'g')
ax5.plot(labels_2, np_numbers, marker = 'o', color = 'c')
ax2.set_title('Conversions')
ax3.set_title('Clicks')
ax4.set_title('Impressions')
ax2.set_xlabel('Month')
ax2.set_ylabel('Count')
ax3.set_xlabel('Month')
ax3.set_ylabel('Count')
ax4.set_xlabel('Month')
ax4.set_ylabel('Count')
ax5.set_title('New Patients')
ax5.set_xlabel('Month')
ax5.set_ylabel('Count')
labels_5 = n_pdx_budget['Date'].values
values_5 = budget_amount_no_dollar
ax5.axhline(y = 15, color = 'r', linestyle = '--', label = 'Ideal')
ax1.plot(labels_5, values_5, marker = 'o')
ax1.set_title('Budget')
ax1.set_xlabel('Month')
ax1.set_ylabel('Amount')
ax1.yaxis.set_major_formatter('${x:1.2f}')
fig.tight_layout()
plt.show()

# %% [markdown]
# ## For all of our current active campaigns, their conversions peaked in September, regardless of the budget price and how long that campain had been running up until the end of September.

# %%
df15 = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\Main Project\\df15.xlsx', index_col = 0)

# %%
df15.iloc[:, [0, 12]].sort_values(by = 'Sep 2023 Conversions', ascending = False)
# Out:
#           Location  Sep 2023 Conversions
# 6         s. salem                303.92
# 0        clackamas                303.75
# 8     e. vancouver                288.28
# 9         woodburn                268.59
# 1          gresham                253.00
# 5        hillsboro                229.57
# 7           ne pdx                218.45
# 3        beaverton                204.45
# 2           tigard                204.45
# 4           keizer                188.87
# 12       vancouver                158.07
# 11          se pdx                144.36
# 15      mcminville                122.02
# 14           salem                108.11
# 13      hazel dell                 84.82
# 10    forest grove                 62.37
# 16  north portland                 57.62

# %% [markdown]
# ## For all of the campaigns, the budget was set at \\$75 per day in September except for Hazel Dell, which was set at \\$35 per day.

# %%
df12 = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\Main Project\\conversions and pms.xlsx', index_col = 0)

# %%
df12
# Out:
#                                              Campaign  Conversions  \
# 0   G. Gresham, OR | P. Max | 5 Miles (Presence) |...       342.68
# 1   S. South Salem, OR  | P. Max | 5 miles (P or I...       330.42
# 2   C. Clackamas, OR | P. Max | 5 Miles + 11 Zips ...       323.08
# 3   B. Beaverton, OR | P. Max | 5 Miles, Top 8 Zip...       311.24
# 4   E. Vancouver, WA | P. Max | Custom Locations (...       306.45
# 5   W. Woodburn, OR | P. Max | 5 miles (Presence) ...       292.60
# 6   H. Hillsboro, OR | P. Max | 5 miles (P. or I.)...       268.38
# 7   N.E. Portland, OR | P. Max | 5 miles (Presence...       242.85
# 8   T. Tigard, OR | P. Max | 5 miles (Presence) | ...       227.27
# 9   K. Keizer, OR | P. Max | 5 miles (P or I) | Es...       221.74
# 10  V. Vancouver, WA | P. Max | 5 miles (Presence)...       182.57
# 11  S.E. Portland, OR | P. Max | 5 miles (Presence...       173.05
# 12  S. Salem, OR | P. Max | 5 miles (P or I) | Est...       135.10
# ...

# %% [markdown]
# ## Below are the correlations between our performance metrics and the total number of conversions:

# %%
df12.iloc[:, [1, 3, 4]].corr()['Conversions']
# Out:
# Conversions                       1.000000
# Average Number Minus Ideal        0.701128
# Proportion of Actual to Target    0.695353
# Name: Conversions, dtype: float64

# %%
df15.iloc[:, [1, 2, 12]].corr()['Sep 2023 Conversions']
# Out:
# Avg Number Minus Ideal            0.754322
# Proportion of Actual to Target    0.745980
# Sep 2023 Conversions              1.000000
# Name: Sep 2023 Conversions, dtype: float64

# %%
df21 = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\Main Project\\df21.xlsx', index_col = 0)

# %%
df21 = df21.iloc[:, [0, 1, 3, 2, 4]].sort_values(by = 'Average Minus Ideal_x', ascending = False)

# %%
df21.reset_index(inplace = True, drop = True)

# %%
df22 = pd.merge(df21, df11.iloc[:, [1, 2]], on = 'Location', how = 'outer')

# %%
df22.drop([15, 16], axis = 0, inplace = True)

# %%
df22['Average Minus Ideal_x'] = df22['Average Minus Ideal_x'].astype(int)
df22['Average Minus Ideal_y'] = df22['Average Minus Ideal_y'].astype(int)

# %%
def highlight(df):
   return['background-color: lightgreen' if df22['Average Minus Ideal_x'][i] < df22['Average Minus Ideal_y'][i]
          else 'background-color: pink' if df22['Average Minus Ideal_x'][i] == df22['Average Minus Ideal_y'][i]
          else 'background-color: lightcoral' if df22['Average Minus Ideal_x'][i] > df22['Average Minus Ideal_y'][i]
          else '' for i in range(df.shape[0])]

# %%
df22.style.apply(highlight, axis = 0)
# Out:
# <style type="text/css">
# #T_c68aa_row0_col0, #T_c68aa_row0_col1, #T_c68aa_row0_col2, #T_c68aa_row0_col3, #T_c68aa_row0_col4, #T_c68aa_row0_col5, #T_c68aa_row2_col0, #T_c68aa_row2_col1, #T_c68aa_row2_col2, #T_c68aa_row2_col3, #T_c68aa_row2_col4, #T_c68aa_row2_col5, #T_c68aa_row9_col0, #T_c68aa_row9_col1, #T_c68aa_row9_col2, #T_c68aa_row9_col3, #T_c68aa_row9_col4, #T_c68aa_row9_col5, #T_c68aa_row10_col0, #T_c68aa_row10_col1, #T_c68aa_row10_col2, #T_c68aa_row10_col3, #T_c68aa_row10_col4, #T_c68aa_row10_col5, #T_c68aa_row11_col0, #T_c68aa_row11_col1, #T_c68aa_row11_col2, #T_c68aa_row11_col3, #T_c68aa_row11_col4, #T_c68aa_row11_col5, #T_c68aa_row12_col0, #T_c68aa_row12_col1, #T_c68aa_row12_col2, #T_c68aa_row12_col3, #T_c68aa_row12_col4, #T_c68aa_row12_col5, #T_c68aa_row14_col0, #T_c68aa_row14_col1, #T_c68aa_row14_col2, #T_c68aa_row14_col3, #T_c68aa_row14_col4, #T_c68aa_row14_col5 {
#   background-color: lightgreen;
# }
# ...

# %% [markdown]
# ## The column "Average Minus Ideal_x" is the first performance metric for all available data before July 2023 and the column "Average Minus Ideal_y" is the first performance metric for all available data after July 2023. The same goes for "Proportion of Actual to Target_x" and "Proportion of Actual to Target_y". Highlighted in green are clinics which improved in these metrics between the two time periods.

# %%
ne_pdx_2 = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\ACS Project 2\\New Patient Numbers Analysis\\ne_pdx_2.xlsx', index_col = 0)

# %%
def highlight_4(df):
   return['background-color: lightcoral' if ne_pdx_2.T['Average Minus Ideal_x'][i] > ne_pdx_2.T['Average Minus Ideal_y'][i]
          else '' for i in range(df.shape[0])]

# %%
ne_pdx_2.T.style.apply(highlight_4, axis = 0)
# Out:
# <style type="text/css">
# #T_2519b_row0_col0, #T_2519b_row0_col1, #T_2519b_row0_col2, #T_2519b_row0_col3, #T_2519b_row0_col4 {
#   background-color: lightcoral;
# }
# </style>
# <table id="T_2519b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2519b_level0_col0" class="col_heading level0 col0" >Location</th>
#       <th id="T_2519b_level0_col1" class="col_heading level0 col1" >Average Minus Ideal_x</th>
#       <th id="T_2519b_level0_col2" class="col_heading level0 col2" >Average Minus Ideal_y</th>
#       <th id="T_2519b_level0_col3" class="col_heading level0 col3" >Proportion of Actual to Target_x</th>
#       <th id="T_2519b_level0_col4" class="col_heading level0 col4" >Proportion of Actual to Target_y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2519b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2519b_row0_col0" class="data row0 col0" >ne pdx</td>
# ...

# %%
df13 = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\Main Project\\online bookings.xlsx', index_col = 0)

# %%
def highlight_2(df):
   return['background-color: lightgreen' if df13['Avg 2'][i] > df13['Avg 1'][i]
          else 'background-color: pink' if df13['Avg 2'][i] < df13['Avg 1'][i]
          else '' for i in range(df.shape[0])]

# %%
df13.style.apply(highlight_2, axis = 0)
# Out:
# <style type="text/css">
# #T_67790_row0_col0, #T_67790_row0_col1, #T_67790_row0_col2, #T_67790_row0_col3, #T_67790_row4_col0, #T_67790_row4_col1, #T_67790_row4_col2, #T_67790_row4_col3, #T_67790_row6_col0, #T_67790_row6_col1, #T_67790_row6_col2, #T_67790_row6_col3, #T_67790_row7_col0, #T_67790_row7_col1, #T_67790_row7_col2, #T_67790_row7_col3, #T_67790_row12_col0, #T_67790_row12_col1, #T_67790_row12_col2, #T_67790_row12_col3, #T_67790_row13_col0, #T_67790_row13_col1, #T_67790_row13_col2, #T_67790_row13_col3 {
#   background-color: pink;
# }
# ...

# %% [markdown]
# ## This is a dataset showing the average number of online bookings for each clinic from two different time periods. 'Avg 1' is average number of online bookings from January 2023 to June 2023, 'Avg 2' is average number of online bookings from July 2023 onwards. The average difference was 0.26 patients.

# %%
df17 = df13[df13['Location'].isin(['se pdx', 'hillsboro', 'keizer', 'beaverton', 'tigard', 'e. vancouver', 'vancouver', 'mcminville', 'ne pdx'])]

# %%
df17.reset_index(inplace = True, drop = True)

# %%
def highlight_5(df):
   return['background-color: lightgreen' if df17['Avg 2'][i] > df17['Avg 1'][i]
          else 'background-color: pink' if df17['Avg 2'][i] < df17['Avg 1'][i]
          else '' for i in range(df.shape[0])]

# %%
df17.style.apply(highlight_5, axis = 0)
# Out:
# <style type="text/css">
# #T_f34e0_row0_col0, #T_f34e0_row0_col1, #T_f34e0_row0_col2, #T_f34e0_row0_col3, #T_f34e0_row4_col0, #T_f34e0_row4_col1, #T_f34e0_row4_col2, #T_f34e0_row4_col3, #T_f34e0_row8_col0, #T_f34e0_row8_col1, #T_f34e0_row8_col2, #T_f34e0_row8_col3 {
#   background-color: pink;
# }
# #T_f34e0_row1_col0, #T_f34e0_row1_col1, #T_f34e0_row1_col2, #T_f34e0_row1_col3, #T_f34e0_row2_col0, #T_f34e0_row2_col1, #T_f34e0_row2_col2, #T_f34e0_row2_col3, #T_f34e0_row3_col0, #T_f34e0_row3_col1, #T_f34e0_row3_col2, #T_f34e0_row3_col3, #T_f34e0_row5_col0, #T_f34e0_row5_col1, #T_f34e0_row5_col2, #T_f34e0_row5_col3, #T_f34e0_row6_col0, #T_f34e0_row6_col1, #T_f34e0_row6_col2, #T_f34e0_row6_col3, #T_f34e0_row7_col0, #T_f34e0_row7_col1, #T_f34e0_row7_col2, #T_f34e0_row7_col3 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f34e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %%
df14 = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\ACS Referral Data\\df.xlsx', index_col = 0)

# %%
df14
# Out:
#       Location  Proportion of online vs. rest
# 0        n_pdx                          48.65
# 1   hazel_dell                          42.22
# 2        clack                          36.19
# 3         bend                          34.21
# 4          mcm                          31.76
# 5        gresh                          30.77
# 6       tigard                          26.79
# 7         beav                          26.32
# 8        hills                          24.31
# 9       keizer                          22.45
# 10         van                          21.69
# 11          fg                          20.74
# 12       e_van                          18.82
# 13          ne                          17.24
# 14          se                          16.45
# 15       salem                          15.21
# 16     s_salem                          14.67
# 17        wood                          11.64

# %% [markdown]
# ## This dataset the percentage of new patients which came from online compared to all other methods. The data spans from January 2023 all the way to February 2024. North Portland and Hazel Dell have very high percentages, but they have very small sample sizes. The mean percentage of online versus all other methods is 23.08% (excluding North PDX and Hazel Dell).

# %%
df14[df14['Location'].isin(['se', 'hills', 'keizer', 'beav', 'tigard', 'e_van', 'van', 'mcm', 'ne'])]
# Out:
#    Location  Proportion of online vs. rest
# 4       mcm                          31.76
# 6    tigard                          26.79
# 7      beav                          26.32
# 8     hills                          24.31
# 9    keizer                          22.45
# 10      van                          21.69
# 12    e_van                          18.82
# 13       ne                          17.24
# 14       se                          16.45

# %%
df16 = pd.read_excel('C:\\Users\\19713\\Desktop\\ACS\\ACS Referral Data\\df2.xlsx', index_col = 0)

# %%
def highlight_3(df):
   return['background-color: lightgreen' if df16['Proportion 1'][i] < df16['Proportion 2'][i]
          else '' for i in range(df.shape[0])]

# %%
df16.style.apply(highlight_3, axis = 0)
# Out:
# <style type="text/css">
# #T_7809d_row1_col0, #T_7809d_row1_col1, #T_7809d_row1_col2, #T_7809d_row3_col0, #T_7809d_row3_col1, #T_7809d_row3_col2, #T_7809d_row6_col0, #T_7809d_row6_col1, #T_7809d_row6_col2, #T_7809d_row9_col0, #T_7809d_row9_col1, #T_7809d_row9_col2, #T_7809d_row10_col0, #T_7809d_row10_col1, #T_7809d_row10_col2, #T_7809d_row11_col0, #T_7809d_row11_col1, #T_7809d_row11_col2, #T_7809d_row13_col0, #T_7809d_row13_col1, #T_7809d_row13_col2, #T_7809d_row14_col0, #T_7809d_row14_col1, #T_7809d_row14_col2 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_7809d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7809d_level0_col0" class="col_heading level0 col0" >Location</th>
#       <th id="T_7809d_level0_col1" class="col_heading level0 col1" >Proportion 1</th>
#       <th id="T_7809d_level0_col2" class="col_heading level0 col2" >Proportion 2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ## 'Proportion 1' corresponds to the percentage of new patients who came from online from January 2023 to June 2023. 'Proportion 2' is similar to 'Proportion 1' but spans the months of July 2023 to February 2024.

# %% [markdown]
# # Recommendations: Increase the budgets for those clinics which did not improve between the two time periods and also have not had any budget adjustments since they were created. These clinics are: SE PDX, Hillsboro, Keizer, Beaverton, Tigard, East Vancouver, Vancouver, McMinville, and NE PDX.
#
# # We will treat the other locations as a control group to compare the performance of those clinics with a higher budgets versus those clinics who will continue to have a set budget of $75/day.
